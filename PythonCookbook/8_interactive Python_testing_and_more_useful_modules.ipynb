# %%
gtf = 'transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"'
gtf_list = gtf.split(" ")
print gtf_list
print gtf_list[8].find('ENS')
print gtf_list[8][1:].find('"')
def get_ensemble_id(gtf_list):
 
    if len(gtf_list) == 9:
 
        ##ids should all start with ENS
        ensID_start = gtf_list[8].find('ENS')
        ##the id ends with a ", so find the next " after the start
        ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
        return gtf_list[8][ensID_start:ensID_end]
    
get_ensemble_id(gtf_list)
# Out:
# ['transcribed_unprocessed_pseudogene', 'gene', '11869', '14409', '.', '+', '.', 'gene_id', '"ENSG00000223972"']
# 1
# 15
# 'ENSG00000223972'

# %%
##input: a list of strings gtf_list (from a line of a GTF file)
##output: the ensemble id from gtf_list
def get_ensemble_id(gtf_list):
 
    if is_valid_gtf(gtf_list):
        return find_ensID(gtf_list)
 
##input: a list of strings gtf_list (from a line of a GTF file)
##output: a boolean, True if the list has 9 elements
def is_valid_gtf(gtf_list):
    return len(gtf_list) == 9
    ## GTF files have 9 fields
    ##http://uswest.ensembl.org/info/website/upload/gff.html
 
##input: a list of strings gtf_list (from a line of a GTF file)
##output: the ensemble id from gtf_list
def find_ensID(gtf_list):
 
    annotation = gtf_list[8]
    ##ids should all start with ENS
    ensID_start = annotation.find('ENS')
    ##the id ends with a ", so find the next " after the start
    ensID_end = annotation[ensID_start:].find('"') + ensID_start
    return annotation[ensID_start:ensID_end]

print get_ensemble_id(gtf_list)
# Out:
# ENSG00000223972

# %%
help(dir)
# Out:
# Help on built-in function dir in module __builtin__:
#
# dir(...)
#     dir([object]) -> list of strings
#
#     If called without an argument, return the names in the current scope.
#     Else, return an alphabetized list of names comprising (some of) the attributes
#     of the given object, and of attributes reachable from it.
#     If the object supplies a method named __dir__, it will be used; otherwise
#     the default dir() logic is used and returns:
#       for a module object: the module's attributes.
#       for a class object:  its attributes, and recursively the attributes
#         of its bases.
#       for any other object: its attributes, its class's attributes, and
#         recursively the attributes of its class's base classes.

# %%
dir(gtf)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__getslice__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '_formatter_field_name_split',
#  '_formatter_parser',
#  'capitalize',
#  'center',
#  'count',
#  'decode',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isdigit',
#  'islower',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
# %%bash
# ls -l
# Out:
# total 64
# -rw-r--r--  1 DONG  staff  11599 Jul 24 23:22 7_functions_modules_and_code_reuse.ipynb
# -rw-r--r--  1 DONG  staff   6665 Jul 25 09:54 8_Interactive Python_testing_and_more_useful_modules.ipynb
# -rwxr-xr-x@ 1 DONG  staff    280 Jul 24 22:52 greeting_module.py
# -rw-r--r--  1 DONG  staff    549 Jul 24 22:53 greeting_module.pyc
# -rwxr-xr-x@ 1 DONG  staff     74 Jul 24 08:12 testprogram.py

# %%
# %pwd
# Out:
# u'/Users/DONG/Documents/Python/Python_world/4_reading_writing_using_lots_of_data'

# %%
# %hist -nt
# Out:
#    1:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf
#    2:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf_list
#    3:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    4:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    5:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    6:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    7:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    8:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][ensID_start:]
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    9:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:]
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   10:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:9]
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   11:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:9].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   12:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   13:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   14:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][0:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   15:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][2:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   16:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   17:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   18:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"'''
# gtf_list = gtf.split(" ")
# print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   19:
# gtf = 'transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"'
# gtf_list = gtf.split(" ")
# print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   20:
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def get_ensemble_id(gtf_list):
#
#     if is_valid_gtf(gtf_list):
#         return find_ensID(gtf_list)
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: a boolean, True if the list has 9 elements
# def is_valid_gtf(gtf_list):
#     return len(gtf_list) == 9
#     ## GTF files have 9 fields
#     ##http://uswest.ensembl.org/info/website/upload/gff.html
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def find_ensID(gtf_list):
#
#     annotation = gtf_list[8]
#     ##ids should all start with ENS
#     ensID_start = annotation.find('ENS')
#     ##the id ends with a ", so find the next " after the start
#     ensID_end = annotation[ensID_start:].find('"') + ensID_start
#     return annotation[ensID_start:ensID_end]
#   21:
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def get_ensemble_id(gtf_list):
#
#     if is_valid_gtf(gtf_list):
#         return find_ensID(gtf_list)
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: a boolean, True if the list has 9 elements
# def is_valid_gtf(gtf_list):
#     return len(gtf_list) == 9
#     ## GTF files have 9 fields
#     ##http://uswest.ensembl.org/info/website/upload/gff.html
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def find_ensID(gtf_list):
#
#     annotation = gtf_list[8]
#     ##ids should all start with ENS
#     ensID_start = annotation.find('ENS')
#     ##the id ends with a ", so find the next " after the start
#     ensID_end = annotation[ensID_start:].find('"') + ensID_start
#     return annotation[ensID_start:ensID_end]
#
# print get_ensemble_id(gtf_list)
#   22: help(dir)
#   23: dir(gtf_list)
#   24: dir(gtf)
#   25: get_ipython().magic(u'ls ')
#   26: get_ipython().run_cell_magic(u'bash', u'', u'ls -l')
#   27: get_ipython().magic(u'history')
#   28: get_ipython().magic(u'ls')
#   29: get_ipython().magic(u'la')
#   30: get_ipython().magic(u'cd ..')
#   31: get_ipython().magic(u'pwd')
#   32: get_ipython().magic(u'cd /Users/DONG/Documents/Python/Python_world/4_reading_writing_using_lots_of_data/')
#   33: get_ipython().magic(u'pwd')
#   34: get_ipython().magic(u'hist -nt')

# %%
# %save histfile.py 32-34
# Out:
# File `histfile.py` exists. Overwrite (y/[N])?  y
# The following commands were written to file `histfile.py`:
# get_ipython().magic(u'cd /Users/DONG/Documents/Python/Python_world/4_reading_writing_using_lots_of_data/')
# get_ipython().magic(u'pwd')
# get_ipython().magic(u'hist -nt')

# %%
run histfile
# Out:
# /Users/DONG/Documents/Python/Python_world/4_reading_writing_using_lots_of_data
#    1:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf
#    2:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf_list
#    3:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    4:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    5:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    6:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    7:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
#
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    8:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][ensID_start:]
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#    9:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:]
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   10:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:9]
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   11:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:9].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   12:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   13:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   14:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][0:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   15:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][2:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   16:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# #print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   17:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"; gene_name "DDX11L1"; gene_source "havana"; gene_biotype "transcribed_unprocessed_pseudogene";'''
# gtf_list = gtf.split(" ")
# print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     #if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   18:
# gtf = '''transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"'''
# gtf_list = gtf.split(" ")
# print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   19:
# gtf = 'transcribed_unprocessed_pseudogene gene 11869 14409 . + . gene_id "ENSG00000223972"'
# gtf_list = gtf.split(" ")
# print gtf_list
# print gtf_list[8].find('ENS')
# print gtf_list[8][1:].find('"')
# def get_ensemble_id(gtf_list):
#
#     if len(gtf_list) == 9:
#
#         ##ids should all start with ENS
#         ensID_start = gtf_list[8].find('ENS')
#         ##the id ends with a ", so find the next " after the start
#         ensID_end = gtf_list[8][ensID_start:].find('"') + ensID_start
#         return gtf_list[8][ensID_start:ensID_end]
#
# get_ensemble_id(gtf_list)
#   20:
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def get_ensemble_id(gtf_list):
#
#     if is_valid_gtf(gtf_list):
#         return find_ensID(gtf_list)
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: a boolean, True if the list has 9 elements
# def is_valid_gtf(gtf_list):
#     return len(gtf_list) == 9
#     ## GTF files have 9 fields
#     ##http://uswest.ensembl.org/info/website/upload/gff.html
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def find_ensID(gtf_list):
#
#     annotation = gtf_list[8]
#     ##ids should all start with ENS
#     ensID_start = annotation.find('ENS')
#     ##the id ends with a ", so find the next " after the start
#     ensID_end = annotation[ensID_start:].find('"') + ensID_start
#     return annotation[ensID_start:ensID_end]
#   21:
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def get_ensemble_id(gtf_list):
#
#     if is_valid_gtf(gtf_list):
#         return find_ensID(gtf_list)
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: a boolean, True if the list has 9 elements
# def is_valid_gtf(gtf_list):
#     return len(gtf_list) == 9
#     ## GTF files have 9 fields
#     ##http://uswest.ensembl.org/info/website/upload/gff.html
#
# ##input: a list of strings gtf_list (from a line of a GTF file)
# ##output: the ensemble id from gtf_list
# def find_ensID(gtf_list):
#
#     annotation = gtf_list[8]
#     ##ids should all start with ENS
#     ensID_start = annotation.find('ENS')
#     ##the id ends with a ", so find the next " after the start
#     ensID_end = annotation[ensID_start:].find('"') + ensID_start
#     return annotation[ensID_start:ensID_end]
#
# print get_ensemble_id(gtf_list)
#   22: help(dir)
#   23: dir(gtf_list)
#   24: dir(gtf)
#   25: get_ipython().magic(u'ls ')
#   26: get_ipython().run_cell_magic(u'bash', u'', u'ls -l')
#   27: get_ipython().magic(u'history')
#   28: get_ipython().magic(u'ls')
#   29: get_ipython().magic(u'la')
#   30: get_ipython().magic(u'cd ..')
#   31: get_ipython().magic(u'pwd')
#   32: get_ipython().magic(u'cd /Users/DONG/Documents/Python/Python_world/4_reading_writing_using_lots_of_data/')
#   33: get_ipython().magic(u'pwd')
#   34: get_ipython().magic(u'hist -nt')
#   35: get_ipython().magic(u'save histfile.py 19-24')
#   36: get_ipython().magic(u'save histfile.py 1')
#   37: get_ipython().magic(u'run histfile')
#   38: get_ipython().magic(u'save histfile.py 21-22')
#   39: get_ipython().magic(u'run histfile')
#   40: get_ipython().magic(u'run histfile')
#   41: get_ipython().magic(u'save histfile.py 32-34')
#   42: get_ipython().magic(u'run histfile')
#   43: get_ipython().magic(u'ls ')
#   44: get_ipython().magic(u'run testprogram')
#   45: get_ipython().magic(u'run testprogram.py')
#   46: get_ipython().magic(u'save hist.py 32-34')
#   47: get_ipython().magic(u'run hist')
#   48: get_ipython().magic(u'edit histfile')
#   49: get_ipython().magic(u'edit histfile')
#   50: get_ipython().magic(u'edit histfile.py')
#   51: get_ipython().magic(u'save histfile.py 32-34')
#   52: get_ipython().magic(u'run histfile')

# %%
# %edit histfile

# %%
gtf_list.append?

# %%
def fastaParser(filename):
   current_gene = ""
   genes = {}
   fh = open(filename, 'r')
 
   for line in fh:
       line = line.strip()
       if line.startswith('>'):
           current_gene = line[1:]
           genes[current_gene] = ''
       else:
            join(genes, current_gene, line)
 
   return genes
 
 
def join(gene_dict, gene, line):
    gene_dict[gene] += line
 

c_elegans = fastaParser('ceWS215_tRNA.fa')
 
print "There are", len(c_elegans), "chromosomes in C.elegans"
# Out:
# There are 660 chromosomes in C.elegans

# %%
def fastaParser2(filename):
   current_gene = ""
   genes = {}
   fh = open(filename, 'r')
 
   for line in fh:
       line = line.strip()
       if line.startswith('>'):
           current_gene = line[1:]
           genes[current_gene] = []
       else:
            join2(genes, current_gene, line)
 
   for gene in genes:
       genes[gene] = ''.join(genes[gene])
 
   return genes
 
 
def join2(gene_dict, gene, line):
    gene_dict[gene].append(line)
 
yeast_genome = fastaParser2('ceWS215_tRNA.fa')
 
print "There are", len(yeast_genome), "chromosomes in yeast"

# %%
run parse_genome.py
# Out:
# There are 660 chromosomes in C.elegans

# %%
run -p parse_genome.py
